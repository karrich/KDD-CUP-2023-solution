# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = str(3)
# !python -u main.py --gpu_id 0 --batch_size 8192 --lion 0 --wd 0.001 --save_number 3 --hidden_units=128 --train 1 --seq_len 2
# Out:
# Namespace(batch_size=8192, device='cuda', dropout_rate=0.2, epochs=100, gpu_id=0, hidden_units=128, l2_emb=0.0, lion=0, lr=0.001, max_=None, maxlen=50, model_path='0.2642.pt', num_blocks=2, num_heads=1, patience=1, save_number=3, seed=0, seq_len=2, train=1, wd=0.001)
# 15823909 16364
# ----------------Training-Step1----------------
# 100%|███████████████████████████████████████| 1932/1932 [05:50<00:00,  5.52it/s]
# Epoch [1 / 100]: loss=3.1994347286026916
#  4999 / 16364 16364/ 163641636416364Epoch:1, MRR@10: 0.3008, NDCG@10: 0.3744, HR@10: 0.6616
# 100%|███████████████████████████████████████| 1932/1932 [06:07<00:00,  5.26it/s]
# Epoch [2 / 100]: loss=2.379803668885004
#  4999 / 16364 / 16364Epoch:2, MRR@10: 0.3070, NDCG@10: 0.3835, HR@10: 0.6808
# 100%|███████████████████████████████████████| 1932/1932 [05:57<00:00,  5.40it/s]
# Epoch [3 / 100]: loss=2.1133825532768085
#  4999 / 163646364 16364Epoch:3, MRR@10: 0.3063, NDCG@10: 0.3833, HR@10: 0.6824
# ...
